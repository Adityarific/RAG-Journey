# %% [markdown]
# ![image.png](attachment:2507e78e-f907-496c-b3cf-e0a91bf11197.png)

# %% [markdown]
# ___

# %% [markdown]
# # RAG means (Retrival Augumented Generation)
# ### 1. Retrival = Retriving relevant data from KNowledge Base- ( Created by your personal Data ) or
# #### *Indexed context from data base*
# ### 2. Augumented = Merging retreved data with Users Query ( Making Augumented prompt For - LLM )
# ### 3. Generation = Generating Response on Based on Augumentaed prompt
#
# #### Response based on Augumented prompt based on Retreved data based on indexed context data from Personal Data dataBase( in form of vector )

# %% [markdown]
# ___

# %% [markdown]
# # RAG Pipeline :
# #### Response based on --> Augumented prompt based on --> Retreved data based on --> indexed context data from --> Personal Data dataBase( in form of vector )

# %% [markdown]
# # Steps --->

# %% [markdown]
# ### 1. Indexing

# %% [markdown]
# ##### Document Ingestion : pdf , Reports , Transcripts , GIT repo , Blog , Web , SQL records
# ##### Text Chuncking : Break Data into Meaningful Segmented Chunks
# ##### Embedding Generation :  converting Chunks into Vectors using Embeddings
# ##### Storage : Store vectors in vector Storage

# %% [markdown]
# ### 2. Retreval

# %% [markdown]
# ### 3. Augumented

# %% [markdown]
# ### 4. Generation

# %% [markdown]
# ## Document Ingestion
# ##### TextLoader (.txt)
# ##### PDFLoader (.pdf)
# ##### WebBaseLoader (.web)
# ##### CSVLoader (.csv)

# %% [markdown]
# ## TextLoading RAG
